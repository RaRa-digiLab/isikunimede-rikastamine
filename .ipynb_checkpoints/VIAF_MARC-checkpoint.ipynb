# %%
import requests
import json
import pandas as pd
from pymarc import MARCReader, MARCWriter, Record, Field, Subfield

# %%
# Creating two files – input and output.
input_file = 'VIAF_person_toodeldud.mrc'
output_file = 'VIAF_person_updated.mrc'

# %%
def process_marc_records(input_marc_file_path, output_marc_file_path, num_records_to_process=None):
    # Opening the input file for reading
    with open(input_marc_file_path, 'rb') as input_marc_file:
        # Creating a MARCReader for reading the input file
        reader = MARCReader(input_marc_file)

        # Creating a MARCWriter for writing the output file
        with open(output_marc_file_path, 'wb') as output_marc_file:
            writer = MARCWriter(output_marc_file)

            # Processing records
            for record_count, record in enumerate(reader):
                # Extracting the identifier from the record
                identifier = record['001'].value()

                # Making a request to VIAF API
                viaf_response = requests.get(f'https://www.viaf.org/viaf/sourceID/ERRR|{identifier}/justlinks.json')

                # Check if the request was successful
                if viaf_response.status_code == 200:
                    try:
                        viaf_data = viaf_response.json()

                        # Extracting ISNI, VIAF, and WKP codes
                        isni_code = viaf_data.get('ISNI', [''])[0] if 'ISNI' in viaf_data else ''
                        viaf_code = viaf_data.get('viafID', '') if 'viafID' in viaf_data else ''
                        wkp_code = viaf_data.get('WKP', [''])[0] if 'WKP' in viaf_data else ''

                        # Finding the index of the last fixed field manually
                        last_fixed_index = -1
                        for i, field in enumerate(record.fields):
                            if isinstance(field, Field) and field.is_control_field():
                                last_fixed_index = i

                        # Creating a new list of fields
                        new_fields = []

                        # Copying existing fields up to the last fixed field
                        new_fields.extend(record.fields[:last_fixed_index + 1])

                        # New 024 field for ISNI (if existing)
                        if isni_code:
                            new_fields.append(Field(
                                tag='024',
                                indicators=['7', ' '],
                                subfields=[
                                    Subfield('a', f'{isni_code}'),
                                    Subfield('2', 'isni')
                                ]
                            ))

                        # New 024 field for VIAF (if existing)
                        if viaf_code:
                            new_fields.append(Field(
                                tag='024',
                                indicators=['7', ' '],
                                subfields=[
                                    Subfield('a', f'http://viaf.org/viaf/{viaf_code}'),
                                    Subfield('2', 'uri')
                                ]
                            ))

                        # New 024 field for Wikidata (if existing)
                        if wkp_code:
                            new_fields.append(Field(
                                tag='024',
                                indicators=['8', ' '],
                                subfields=[
                                    Subfield('a', f'https://www.wikidata.org/wiki/{wkp_code}')
                                ]
                            ))

                        # Adding the remaining fields
                        new_fields.extend(record.fields[last_fixed_index + 1:])
                        record.fields = new_fields

                        # Writing the output file
                        writer.write(record)


                    except ValueError as e:
                        print(f"Error parsing VIAF response JSON: {e}")
                else:
                    print(f"VIAF API request failed with status code {viaf_response.status_code}")

                # Checking if a specific number of records to process is specified
                if num_records_to_process is not None and record_count + 1 >= num_records_to_process:
                    break

    # Closing the MARC files
    input_marc_file.close()
    output_marc_file.close()

process_marc_records('VIAF_person_toodeldud.mrc', 'VIAF_person_updated.mrc', num_records_to_process=10)

# %%
marc_file_path = 'VIAF_person_updated.mrc'

# Opening the file
with open(marc_file_path, 'rb') as marc_file:
    reader = MARCReader(marc_file)

    # Processing all the records
    for index, record in enumerate(reader):
        # Printing the entire MARC record as a human-readable string
        print(str(record))
# Out:
# =LDR  00684nz  a2200193n  4500
# =001  a11124167
# =003  ErRR
# =008  990324|n|adnnnaabn\\\\\\\\\\\|\|a|\\\\\\
# =024  7\$a0000000120981326$2isni
# =024  7\$ahttp://viaf.org/viaf/17823$2uri
# =024  8\$ahttps://www.wikidata.org/wiki/Q502
# =040  \\$aErRR$best$cErRR$dErTUR
# =100  0\$aStendhal,$cpseudonüüm,$d1783-1842.
# =400  1\$aBeyle, Marie Henri,$d1783-1842.
# =400  1\$aБейль, Анри Мари,$d1783-1842.
# =400  1\$aStendhal,$cpseud.,$d1783-1842.
# =400  1\$aСтендаль,$cпсевд.,$d1783-1842.
# =670  \\$aEE, 8. kd., 1995; БСЭ, 24, 1976.
# =680  \\$iPrantsuse kirjanik, kodanikunimega Marie Henri Beyle.
#
# =LDR  00644nz  a2200169n  4500
# =001  a11124179
# =003  ErRR
# =008  990217|n\adnnnaabn\\\\\\\\\\\|\|a|\\\\\\
# =024  7\$a0000000122796570$2isni
# =024  7\$ahttp://viaf.org/viaf/49228757$2uri
# =024  8\$ahttps://www.wikidata.org/wiki/Q9061
# =040  \\$aErRR$best$cErRR$dErTUR$dErTrtKR
# =100  1\$aMarx, Karl,$d1818-1883.
# =400  1\$aMarx, Károly,$d1818-1883.
# =400  1\$aМаркс, Карл,$d1818-1883.
# =670  \\$aENE, 5. kd., 1973 ; EE, 6. kd., 1992 ; Meyers neues Lexikon, 9. kd., 1974.
# =680  \\$iSaksa filosoof, majandusteadlane ja kommunistliku liikumise rajaja. Arendas Hegeli dialektikat.
#
# =LDR  00601nz  a2200205n  4500
# =001  a11124180
# =003  ErRR
# =008  990111|n|adnnnaabn\\\\\\\\\\||\|a|\\\\\\
# =024  7\$a0000000122424494$2isni
# =024  7\$ahttp://viaf.org/viaf/96987389$2uri
# =024  8\$ahttps://www.wikidata.org/wiki/Q7243
# =040  \\$aErRR$best$cErRR$dErTUR
# =100  1\$aTolstoi, Lev,$d1828-1910.
# =400  1\$aTolstoi, Leo.
# =400  1\$aTolstoj, Leo.
# =400  1\$aTolstoy, Leo.
# =400  1\$aTolstoi, Léon.
# =400  1\$aТолстой, Лев Николаевич,$d1828-1910.
# =670  \\$aEE, 9. kd., 1996.
# =680  \\$iVene kirjanik.
#
# =LDR  00375nz  a2200133n  4500
# =001  a11124192
# =003  ErRR
# =008  981229|n|adnnnaabn\\\\\\\\\\||\|a|\\\\\\
# =024  7\$ahttp://viaf.org/viaf/1149542954500302747$2uri
# =040  \\$aErRR$best$cErRR$dErEPUR
# =043  \\$cee
# =100  1\$aRaa, Hell,$d1911-1996.
# =670  \\$aKosmeetika: 84 aastat kortsudeta, 1998.
# =680  \\$iLoodusravi propageerija.
#
# =LDR  00477nz  a2200169n  4500
# =001  a11124209
# =003  ErRR
# =008  001027|n|adnnnaabn\\\\\\\\\\|n\aan\\\\\\
# =024  7\$ahttp://viaf.org/viaf/146149542590900300633$2uri
# =040  \\$aErRR$best$cErRR
# =043  \\$cee
# =100  1\$aTraat, Victoria,$d1942-
# =400  1\$aViir, Victoria.
# =400  1\$aViires, Victoria.
# =400  1\$aTraat, Viktoria.
# =670  \\$aEesti kirjanike leksikon. Tallinn, 2000.
# =680  \\$iEesti tõlkija. A-ni 1970 Viir.
#
# =LDR  00602nz  a2200193n  4500
# =001  a11124210
# =003  ErRR
# =008  990107|n|adnnnaabn\\\\\\\\\\||\|a|\\\\\\
# =024  7\$a0000000108767554$2isni
# =024  7\$ahttp://viaf.org/viaf/19794432$2uri
# =024  8\$ahttps://www.wikidata.org/wiki/Q438409
# =040  \\$aErRR$best$cErRR$dErTUR$dErTrtKR
# =043  \\$cee
# =100  1\$aVetemaa, Enn,$d1936-2017.
# =400  1\$aVetemā, Enns.
# =400  1\$aВетемаа, Энн,$d1936-2017.
# =400  1\$aВетемаа, Енн
# =670  \\$aEesti kirjanike leksikon, 2000.
# =680  \\$iEesti prosaist, näitekirjanik ja luuletaja.
#
# =LDR  00918nz  a2200217n  4500
# =001  a11124222
# =003  ErRR
# =008  990120|n|adnnnaabn\\\\\\\\\\||\|a|\\\\\\
# =024  7\$a0000000121317777$2isni
# =024  7\$ahttp://viaf.org/viaf/49220707$2uri
# =024  8\$ahttps://www.wikidata.org/wiki/Q80440
# =040  \\$aErEAR$best$cErEAR$dErTUR
# =100  1\$aAhmatova, Anna,$cpseudonüüm,$d1889-1966.
# =400  1\$aAkhmatova, Anna,$d1889-1966.
# =400  1\$aGorenko, Anna Andrejevna,$d1889-1966.
# =400  1\$aGorenko, Anna,$d1889-1966.
# =400  1\$aAhmatova, Anna,$cpseud.,$d1889-1966.
# =400  1\$aАхматова, Анна,$cпсевд.,$d1889-1966.
# =400  1\$aГоренко, Анна Андреевна,$d1889-1966.
# =670  \\$aEE, 1. kd, 1985 ja Большая Советская Энциклопедия, 2, 1970.
# =680  \\$iVene luuletaja, kodanikunimega Anna Andrejevna Gorenko. Tuntud ka tõlkija ja kirjandusteadlasena.
#
# =LDR  01097nz  a2200289n  4500
# =001  a11124234
# =003  ErRR
# =008  990122|n|adnnnaabn\\\\\\\\\\||\|a|\\\\\\
# =024  7\$a0000000121462392$2isni
# =024  7\$ahttp://viaf.org/viaf/104023256$2uri
# =024  8\$ahttps://www.wikidata.org/wiki/Q991
# =040  \\$aErEAR$best$cErEAR$dErRR$dErTUR$dErTrtKR
# =100  1\$aDostojevski, Fjodor,$d1821-1881.
# =400  1\$aDostoyevsky, Fyodor.
# =400  1\$aDostojewski, Fyodor.
# =400  1\$aDostoevsky, Fyodor.
# =400  1\$aDostojevskij, Fjodor.
# =400  1\$aDostojewskij, Fjodor.
# =400  1\$aDostoïevski, Fedor.
# =400  1\$aDostojewfka, F. M.
# =400  1\$aDostojevskis, Fjodors.
# =400  1\$aDostoyevski, Fyodor Mihayloviç
# =400  1\$aDostojewski, Fiodor.
# =400  1\$aDostoievski, Fédor Mikhailovitch
# =400  1\$aДостоевский, Федор Михайлович,$d1821-1881.
# =670  \\$aENE 2, Tallinn, 1987; Kaus, O. "Dostojewski und sein Schicksal", Berlin, 1923 ja "Большая Советская Энциклопедия" 8, Москва, 1972.
# =680  \\$iVene kirjanik.
#
# =LDR  00557nz  a2200169n  4500
# =001  a11124246
# =003  ErRR
# =008  990129|n|adnnnaabn\\\\\\\\\\|n\aan\\\\\\
# =024  7\$a0000000121296240$2isni
# =024  7\$ahttp://viaf.org/viaf/41841418$2uri
# =024  8\$ahttps://www.wikidata.org/wiki/Q25973
# =040  \\$aErRR$best$cErRR$dErTUR$dErTrtKR
# =043  \\$cch$cde
# =100  1\$aHesse, Hermann,$d1877-1962.
# =400  1\$aГессе, Герман,$d1877-1962.
# =670  \\$aEE, 3. kd., 1988.
# =680  \\$iSaksa-šveitsi kirjanik, Nobeli preemia laureaat (1946). Isa pärit Eestist.
#
# =LDR  00660nz  a2200169n  4500
# =001  a11124258
# =003  ErRR
# =008  990203|n|adnnnaabn\\\\\\\\\\||\|a|\\\\\\
# =024  7\$a0000000110665119$2isni
# =024  7\$ahttp://viaf.org/viaf/62670602$2uri
# =024  8\$ahttps://www.wikidata.org/wiki/Q264382
# =040  \\$aErRR$best$cErRR$dErTUR$dErEPUR
# =043  \\$cee
# =100  1\$aRauch, Georg von,$d1904-1991.
# =400  1\$aРаух, Георг фон,$d1904-1991.
# =670  \\$aEE, 8. kd., 1995; EE, 14. kd., 2000.
# =680  \\$iBaltisaksa ajaloolane. Erialaks Eesti linnaajalugu. 1939 siirdus Saksamaale. Pärast sõda kujunes Baltikumi ja Ida-Euroopa ajaloo silmapaistvaks asjatundjaks.

# %%
# Testing
response = requests.get('http://www.viaf.org/viaf/sourceID/ERRR|a11124209/justlinks.json')
response
# Out:
# <Response [200]>

# %%
print(response.text)
# Out:
#   { "viafID":"146149542590900300633",
#     "ERRR":["a11124209"]}

# %%
print(response.json())
# Out:
# {'viafID': '146149542590900300633', 'ERRR': ['a11124209']}
